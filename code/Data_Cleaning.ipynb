# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import warnings
import re
warnings.filterwarnings('ignore')
pd.set_option('display.max_colwidth', 44)

# %%
coffee_og = pd.read_csv('../data/coffee_df_og.csv')
coffee_test = pd.read_csv('../data/coffee_df_test.csv')
type_region = pd.read_csv('../data/coffee_df_with_type_and_region.csv')
coffee = pd.read_csv('../data/coffee_df.csv')
coffee_fix = pd.read_csv('../data/coffee_fix.csv')

# %%
coffee_og.head()
# Out:
#                                           slug  \
# 0  https://www.coffeereview.com/review/wilt...
# 1  https://www.coffeereview.com/review/colo...
# 2  https://www.coffeereview.com/review/yirg...
# 3  https://www.coffeereview.com/review/colo...
# 4  https://www.coffeereview.com/review/pana...
#
#                                       all_text  rating  \
# 0   \n\n\n95\n\n\nJBC Coffee Roasters\nWilt...      95
# 1   \n\n\n95\n\n\nBird Rock Coffee Roasters...      95
# 2   \n\n\n94\n\n\nRegent Coffee\nYirgacheff...      94
# 3   \n\n\n93\n\n\nRegent Coffee\nColombia T...      93
# 4   \n\n\n94\n\n\nTheory Coffee Roasters\nP...      94
#
#                      roaster                                         name
# 0        JBC Coffee Roasters                        Wilton Benitez Geisha
# 1  Bird Rock Coffee Roasters                   Colombia Cerro Azul Geisha
# 2              Regent Coffee                 Yirgacheffe Mengesha Natural
# ...

# %%
coffee_test.head()
# Out:
#                                           slug  \
# 0  https://www.coffeereview.com/review/swee...
# 1  https://www.coffeereview.com/review/flor...
# 2  https://www.coffeereview.com/review/ethi...
# 3  https://www.coffeereview.com/review/ethi...
# 4  https://www.coffeereview.com/review/ethi...
#
#                                       all_text  rating  \
# 0   \n\n\n95\n\n\nA.R.C.\n“Sweety” Espresso...      95
# 1   \n\n\n94\n\n\nA.R.C.\nFlora Blend Espre...      94
# 2   \n\n\n92\n\n\nRevel Coffee\nEthiopia Sh...      92
# 3   \n\n\n92\n\n\nRoast House\nEthiopia Suk...      92
# 4   \n\n\n94\n\n\nBig Creek Coffee Roasters...      94
#
#                      roaster                        name
# 0                     A.R.C.     “Sweety” Espresso Blend
# 1                     A.R.C.        Flora Blend Espresso
# 2               Revel Coffee    Ethiopia Shakiso Mormora
# 3                Roast House          Ethiopia Suke Quto
# 4  Big Creek Coffee Roasters  Ethiopia Gedeb Halo Beriti

# %%
type_region.head()
# Out:
#                                           slug  \
# 0  https://www.coffeereview.com/review/wilt...
# 1  https://www.coffeereview.com/review/colo...
# 2  https://www.coffeereview.com/review/yirg...
# 3  https://www.coffeereview.com/review/colo...
# 4  https://www.coffeereview.com/review/pana...
#
#                                       all_text  rating  \
# 0   \n\n\n95\n\n\nJBC Coffee Roasters\nWilt...      95
# 1   \n\n\n95\n\n\nBird Rock Coffee Roasters...      95
# 2   \n\n\n94\n\n\nRegent Coffee\nYirgacheff...      94
# 3   \n\n\n93\n\n\nRegent Coffee\nColombia T...      93
# 4   \n\n\n94\n\n\nTheory Coffee Roasters\nP...      94
#
#                      roaster                                         name  \
# 0        JBC Coffee Roasters                        Wilton Benitez Geisha
# 1  Bird Rock Coffee Roasters                   Colombia Cerro Azul Geisha
# 2              Regent Coffee                 Yirgacheffe Mengesha Natural
# ...

# %%
coffee.head()
# Out:
#                 location                                       origin  \
# 0     Madison, Wisconsin         Piendamó, Cauca Department, Colombia
# 1  San Diego, California  Trujillo, Valle del Cauca Department, Co...
# 2   Glendale, California  Yirgacheffe growing region, southern Eth...
# 3   Glendale, California                             Tolima, Colombia
# 4    Redding, California        Volcan growing region, western Panama
#
#           roast         est_price    review_date agtron  aroma  acid  body  \
# 0  Medium-Light   $25.00/8 ounces  November 2022  59/81    9.0   9.0   9.0
# 1         Light   $59.00/8 ounces  November 2022  62/80    9.0   9.0   9.0
# 2  Medium-Light  $20.50/12 ounces  November 2022  60/77    9.0   9.0   9.0
# 3  Medium-Light  $20.50/12 ounces  November 2022  59/79    9.0   9.0   8.0
# 4         Light   $45.00/4 ounces  November 2022  62/80    9.0   9.0   9.0
#
#    flavor  aftertaste  with_milk                                       desc_1  \
# ...

# %%
coffee_fix.tail(10)
# Out:
#                                              slug  \
# 2272  https://www.coffeereview.com/review/colo...
# 2273  https://www.coffeereview.com/review/colo...
# 2274  https://www.coffeereview.com/review/rwan...
# 2275  https://www.coffeereview.com/review/ethi...
# 2276  https://www.coffeereview.com/review/tina...
# 2277  https://www.coffeereview.com/review/finc...
# 2278  https://www.coffeereview.com/review/proy...
# 2279  https://www.coffeereview.com/review/finc...
# 2280  https://www.coffeereview.com/review/chac...
# 2281  https://www.coffeereview.com/review/espr...
#
#                                          all_text  rating  \
# 2272   \n\n\n95\n\n\nMagnolia Coffee\nColombia...      95
# 2273   \n\n\n94\n\n\nBird Rock Coffee Roasters...      94
# 2274   \n\n\n94\n\n\nMagnolia Coffee\nRwanda C...      94
# 2275   \n\n\n92\n\n\nSamlin Coffee\nEthiopia G...      92
# 2276   \n\n\n93\n\n\nEl Gran Cafe\nTinamit Tol...      93
# 2277   \n\n\n92\n\n\nEl Gran Cafe\nFinca Patzi...      92
# ...

# %%
country_state = coffee_fix['location'].str.split(',').str[-1]

# %%
coffee_fix['country_state']= country_state

# %%
coffee_fix['location'] = coffee_fix.location.str.rsplit(', ',1).str[0]

# %%
coffee_fix['location'] = coffee_fix['location'].str.strip()
coffee_fix['country_state'] = coffee_fix['country_state'].str.strip()

# %%
coffee_fix['country'] = country_state

# %%
coffee_fix['country'] = coffee_fix['country'].str.strip()

# %%
coffee_fix['country'] = coffee_fix['country'].replace(dict.fromkeys(['Alabama', 'Alaska', 'Arizona', 
                                                                     'Branford Connecticut','Calfornia', 'California',
                                                                     'Californiaa', 'Colorado','Connecticut', 'D.C.', 
                                                                     'Florida', 'Georgia', "Hawai'i", 'Hawaii', 
                                                                     'Hawai’i', 'Idaho', 'Illinois', 'Iowa', 'Kansas',
                                                                     'Kentucky','Los Angeles','Louisiana','MInnesota',
                                                                     'Maine', 'Maryland', 'Massachusetts', 'Michigan',
                                                                     'Minnesota', 'Mississippi', 'Missouri','Montana',
                                                                     'Nevada', 'New Hampshire', 'New Jersey', 
                                                                     'New Mexico','New York','North Carolina','Ohio', 
                                                                     'Oklahoma', 'Oregon','Pennsylvania','Tennessee', 
                                                                     'Texas', 'Vermont', 'Virginia', 'Washingto', 
                                                                     'Washington','Wisconsin', 'Wyoming'], 
                                                                    'United States'))

# %%
coffee_fix = coffee_fix.replace({'country':{'England' : 'United Kingdom' }})

# %%
coffee_fix['country_state'].sort_values(ascending=True).unique()
# Out:
# array(['Alabama', 'Alaska', 'Arizona', 'Australia', 'Belgium',
#        'Branford Connecticut', 'Calfornia', 'California', 'Californiaa',
#        'Canada', 'China', 'Colombia', 'Colorado', 'Connecticut', 'D.C.',
#        'England', 'Florida', 'Georgia', 'Guatemala', "Hawai'i", 'Hawaii',
#        'Hawai’i', 'Honduras', 'Idaho', 'Illinois', 'Indonesia', 'Iowa',
#        'Japan', 'Kansas', 'Kentucky', 'Kenya', 'Laos', 'Los Angeles',
#        'Louisiana', 'MInnesota', 'Maine', 'Malaysia', 'Maryland',
#        'Massachusetts', 'Mexico', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nevada', 'New Hampshire', 'New Jersey',
#        'New Mexico', 'New York', 'North Carolina', 'Ohio', 'Oklahoma',
#        'Oregon', 'Pennsylvania', 'Peru', 'Slovakia', 'South Korea',
#        'Taiwan', 'Tennessee', 'Texas', 'Thailand', 'Uganda',
#        'United Arab Emirates', 'Vermont', 'Virginia', 'Washingto',
#        'Washington', 'Wisconsin', 'Wyoming', nan], dtype=object)

# %%
coffee_fix['country_state'] = coffee_fix['country_state'].replace(dict.fromkeys(['Calfornia', 'Californiaa'], 
                                                                                'California'))

# %%
coffee_fix['country_state'] = coffee_fix['country_state'].replace(dict.fromkeys(["Hawai'i", "Hawai’i"], 
                                                                                'Hawaii'))

# %%
coffee_fix = coffee_fix.replace({'country_state':{'MInnesota' : 'Minnesota' }})

# %%
coffee_fix = coffee_fix.replace({'country_state':{'Washingto' : 'Washington' }})

# %%
coffee_fix = coffee_fix.replace({'country_state':{'Branford Connecticut' : 'Connecticut' }})

# %%
coffee_fix = coffee_fix.replace({'location':{'Toronto' : 'Toronto, Ontario' }})

# %%
coffee_fix_test = coffee_fix[coffee_fix['country'].str.contains(r"Canada", na=False)]

# %%
cananda_country_state = coffee_fix_test['location'].str.split(',').str[-1]
cananda_country_state
# Out:
# 9                 Ontario
# 12       British Columbia
# 29                Ontario
# 30                Ontario
# 31                Ontario
# 128           Nova Scotia
# 163               Ontario
# 212      British Columbia
# 217               Ontario
# 231               Ontario
# 272               Ontario
# 376               Ontario
# 430      British Columbia
# 518      British Columbia
# 544               Ontario
# 647               Ontario
# 738               Ontario
# 812      British Columbia
# 1010              Alberta
# 1011              Alberta
# 1062     British Columbia
# 1098              Ontario
# 1121              Ontario
# 1262         Saskatchewan
# 1263         Saskatchewan
# 1344              Ontario
# 1345              Ontario
# 1346              Ontario
# 1347              Ontario
# 1348              Ontario
# 1460               Quebec
# 2214              Ontario
# Name: location, dtype: object

# %%
coffee_fix_test['country_state']= cananda_country_state

# %%
coffee_fix_test['country_state'].index
# Out:
# Int64Index([   9,   12,   29,   30,   31,  128,  163,  212,  217,  231,  272,
#              376,  430,  518,  544,  647,  738,  812, 1010, 1011, 1062, 1098,
#             1121, 1262, 1263, 1344, 1345, 1346, 1347, 1348, 1460, 2214],
#            dtype='int64')

# %%
indices = [9,12,29,30,31,128,163,212,217,231,272,376,430,518,544,647,738,812,1010,1011,1062,1098,1121,1262,1263,1344,
           1345, 1346, 1347, 1348, 1460, 2214]
coffee_fix.loc[indices,'country_state'] = coffee_fix_test.loc[indices,'country_state']

# %%
coffee_fix[coffee_fix['country'].str.contains(r"Canada", na=False)]
# Out:
#                                              slug  \
# 9     https://www.coffeereview.com/review/ethi...
# 12    https://www.coffeereview.com/review/dire...
# 29    https://www.coffeereview.com/review/outb...
# 30    https://www.coffeereview.com/review/ace-...
# 31    https://www.coffeereview.com/review/keny...
# 128   https://www.coffeereview.com/review/ethi...
# 163   https://www.coffeereview.com/review/icam...
# 212   https://www.coffeereview.com/review/buru...
# 217   https://www.coffeereview.com/review/gaha...
# 231   https://www.coffeereview.com/review/espr...
# 272   https://www.coffeereview.com/review/ethi...
# 376   https://www.coffeereview.com/review/nica...
# 430   https://www.coffeereview.com/review/espr...
# 518   https://www.coffeereview.com/review/boru...
# 544   https://www.coffeereview.com/review/ace-...
# 647   https://www.coffeereview.com/review/keny...
# 738   https://www.coffeereview.com/review/holi...
# 812   https://www.coffeereview.com/review/orga...
# ...

# %%
coffee_fix_test2 = coffee_fix[coffee_fix['country'].str.contains(r"China", na=False)]

# %%
indices_2 = [0, 1, 14, 16, 17, 18, 19, 20, 21, 96, 288, 290, 381, 469, 488, 490, 497, 498, 512, 534, 553, 554, 607, 
             721, 724, 732, 760, 761, 787, 788, 809, 810, 863, 879, 1047, 1058, 1069, 1210, 1234, 1245, 1336, 1538, 
             1586, 1588, 1589, 1590, 1693, 1694, 1696, 1753, 1754, 1762, 2018]
coffee_fix.loc[indices_2,'country_state'] = coffee_fix_test2.loc[indices_2,'location']

# %%
coffee_fix[coffee_fix['country'].str.contains(r"China", na=False)]
# Out:
#                                              slug  \
# 0     https://www.coffeereview.com/review/swee...
# 1     https://www.coffeereview.com/review/flor...
# 14    https://www.coffeereview.com/review/flow...
# 16    https://www.coffeereview.com/review/nutt...
# 17    https://www.coffeereview.com/review/ethi...
# 18    https://www.coffeereview.com/review/blue...
# 19    https://www.coffeereview.com/review/hous...
# 20    https://www.coffeereview.com/review/ethi...
# 21    https://www.coffeereview.com/review/frui...
# 96    https://www.coffeereview.com/review/indo...
# 288   https://www.coffeereview.com/review/h-co...
# 290   https://www.coffeereview.com/review/ethi...
# 381   https://www.coffeereview.com/review/y-3-...
# 469   https://www.coffeereview.com/review/boli...
# 488   https://www.coffeereview.com/review/blos...
# 490   https://www.coffeereview.com/review/keny...
# 497   https://www.coffeereview.com/review/mell...
# 498   https://www.coffeereview.com/review/espr...
# ...

# %%
coffee_fix = coffee_fix.replace({'country_state':{'Kowloon, Hong Kong' : 'Hong Kong' }})

# %%
coffee_fix = coffee_fix.replace({'location':{'Kowloon, Hong Kong' : 'Kowloon' }})

# %%
coffee_fix_test3 = coffee_fix[coffee_fix['country_state'].str.contains(r"Hong Kong", na=False)]
coffee_fix_test3.index
# Out:
# Int64Index([   0,    1,   14,   16,   17,   18,   19,   20,   21,   96,  469,
#              488,  490,  553,  554,  607,  721,  732,  809,  810,  879, 1047,
#             1058, 1069, 1234, 1245, 1538, 1586, 1588, 1589, 1590, 1753, 1754],
#            dtype='int64')

# %%
indices_3 = [0, 1, 14, 16, 17, 18, 19, 20, 21, 96, 469, 488, 490, 553, 554, 607, 721, 732, 809, 810, 879, 1047, 1058, 
             1069, 1234, 1245, 1538, 1586, 1588, 1589, 1590, 1753, 1754]
coffee_fix.loc[indices_3,'country'] = coffee_fix_test3.loc[indices_3,'country_state']

# %%
coffee_fix_test4 = coffee_fix[coffee_fix['country_state'].str.contains(r"Macao", na=False)]
coffee_fix_test4.index
# Out:
# Int64Index([1762, 2018], dtype='int64')

# %%
indices_4 = [1762, 2018]
coffee_fix.loc[indices_4,'country'] = coffee_fix_test4.loc[indices_4,'country_state']

# %%
coffee_fix_test5 = coffee_fix[coffee_fix['country'].str.contains(r"Taiwan", na=False)]
coffee_fix_test5['location'].sort_values(ascending=True).unique()
# Out:
# array(['Banqiao, New Taipei City', 'Caotun, Nantou', 'Changhua',
#        'Changhua County', 'Chia-Yi', 'Chia-Yi City', 'Chiya-Yi',
#        'Douliou City', 'Hsinchu', 'I-Lan City', 'Kaohsiung',
#        'Kaohsiung City', 'Keelung', 'Minxiong, Chia-Yi',
#        'Minxiong, Chia-yi', 'Nantou', 'New Taipei', 'New Taipei City',
#        'Pingtung', 'Songshan District, Taipei City', 'Taiching',
#        'Taichung', 'Taichung City', 'Tainan', 'Tainan City', 'Taipai',
#        'Taipei', 'Taipei City', 'Taitung', 'Taiwan', 'Taoyuan',
#        'Taoyuan City', 'Xinbei', 'Xitun District, Taichung', 'Yilan',
#        'Yuanlin', 'Zhongli', 'Zhubei City', 'Zhuwei'], dtype=object)

# %%
coffee_fix['location'] = coffee_fix['location'].replace(dict.fromkeys(['Banqiao, New Taipei City', 'New Taipei City'],
                                                                      'New Taipei'))

# %%
coffee_fix['location'] = coffee_fix['location'].replace(dict.fromkeys(['Chia-Yi', 'Chia-Yi City', 'Chiya-Yi', 
                                                                       'Minxiong, Chia-Yi', 'Minxiong, Chia-yi'],
                                                                      'Chiayi'))

# %%
coffee_fix['location'] = coffee_fix['location'].replace(dict.fromkeys(['Songshan District, Taipei City', 'Taipai', 
                                                                       'Taipei City'],
                                                                      'Taipei'))

# %%
coffee_fix['location'] = coffee_fix['location'].replace(dict.fromkeys(['Taiching', 'Taichung City', 
                                                                       'Xitun District, Taichung'],
                                                                      'Taichung'))

# %%
coffee_fix['location'] = coffee_fix['location'].replace(dict.fromkeys(['Zhuwei', 'Taoyuan City'],
                                                                      'Taoyuan'))

# %%
coffee_fix = coffee_fix.replace({'location':{'Caotun, Nantou' : 'Nantou',  'Changhua County' : 'Changhua', 
                                             'I-Lan City' : 'Yilan', 'Kaohsiung City' : 'Kaohsiung', 
                                             'Tainan City' : 'Tainan', 'Douliou City' : 'Douliou', 
                                             'Zhubei City' : 'Zhubei'}})

# %%
coffee_fix_test6 = coffee_fix[coffee_fix['country'].str.contains(r"Canada", na=False)]

# %%
coffee_fix = coffee_fix.replace({'location':{'Oakville, Ontario' : 'Oakville',  
                                             'Victoria, British Columbia' : 'Victoria', 
                                             'Toronto, Ontario' : 'Toronto', 'Halifax, Nova Scotia' : 'Halifax', 
                                             'Markham, Ontario' : 'Markham', 
                                             'Richmond, British Columbia' : 'Richmond', 
                                             'Vancouver, British Columbia' : 'Vancouver', 
                                             'Hamilton, Ontario' : 'Hamilton', 
                                             'Gibsons, British Columbia' : 'Gibsons', 
                                             'Calgary, Alberta' : 'Calgary', 
                                             'Lloydminster, Saskatchewan' : 'Lloydminster', 
                                             'Sherbrooke, Quebec' : 'Sherbrooke'}})

# %%
coffee_fix = coffee_fix.replace({'country_state':{'Malaysia' : 'Sabah' }})

# %%
coffee_fix = coffee_fix.replace({'location':{'Kota Kinabalu, Sabah' : 'Kota Kinabalu' }})

# %%
coffee_fix = coffee_fix.replace({'country_state':{'Peru' : 'Satipo Province' }})

# %%
coffee_fix = coffee_fix.replace({'location':{'Llayla District, Satipo Province' : 'Llayla District' }})

# %%
coffee_fix['location'] = coffee_fix['location'].fillna('Hong Kong')

# %%
coffee_fix['country_state'] = coffee_fix['country_state'].fillna('Hong Kong')

# %%
coffee_fix['country'] = coffee_fix['country'].fillna('Hong Kong')

# %%
coffee_fix['country'].sort_values(ascending=True).unique()
# Out:
# array(['Australia', 'Belgium', 'Canada', 'China', 'Colombia', 'Guatemala',
#        'Honduras', 'Hong Kong', 'Indonesia', 'Japan', 'Kenya', 'Laos',
#        'Macao', 'Malaysia', 'Mexico', 'Peru', 'Slovakia', 'South Korea',
#        'Taiwan', 'Thailand', 'Uganda', 'United Arab Emirates',
#        'United Kingdom', 'United States'], dtype=object)

# %%
coffee_fix_test7 = coffee_fix[coffee_fix['roaster'].str.contains(r"A.R.C.", na=False)]

# %%
coffee_fix[coffee_fix.country_state.isnull()]
# Out:
# Empty DataFrame
# Columns: [slug, all_text, rating, roaster, name, location, origin, roast, est_price, review_date, agtron, aroma, acid, body, flavor, aftertaste, with_milk, desc_1, desc_2, desc_3, country_state, country]
# Index: []
#
# [0 rows x 22 columns]

# %%
coffee_fix = coffee_fix.rename(columns={"location": "roaster_city", "country_state": "roaster_country_state", 
                                        "country": "roaster_country"})

# %%
coffee_fix['origin'] = coffee_fix['origin'].str.strip()

# %%
coffee_fix['origin'].sort_values(ascending=True).unique()
# Out:
# array(['Acatenango Valley, Guatemala',
#        'Acatenango growing region, Guatemala',
#        'Acatenango growing region, central Guatemala',
#        'Acatenango, Chimaltenango Department, Guatemala',
#        'Acatenango, Guatemala', 'Aceh Province, Sumatra',
#        'Aceh Province, Sumatra, Indonesia',
#        'Aceh Province, northern Sumatra Indonesia',
#        'Aceh Province, northern Sumatra, Indonesia',
#        'Aceh growing region, Aceh Province, northern Sumatra, Indonesia',
#        'Aceh, Sumatra', 'Aceh, Sumatra, Indonesia',
#        'Acevedo, Huila Department, Colombia', 'Africa',
#        'Africa, South America, Central America', 'Africa; Asia',
#        'Africa; Asia Pacific', 'Africa; Central America',
#        'Africa; Indonesia; South America', 'Africa; South America',
#        'Africa; South America; Central America',
#        'Agaro District, Jimma Zone, west-central Ethiopia',
#        'Agaro Gera, Jimma Zone, Oromia Region, Ethiopia',
# ...

# %%
coffee_fix['origin_count'] = coffee_fix['origin'].str.count(r'(;)') + 1

# %%
coffee_fix['origin_country'] = coffee_fix['origin']

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Sabah State, East Malaysia', 'Sabah State, Malaysia'], 'Malaysia'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Lincong, Yunnan Province, China', 'Yunnan Province, China'], 'China'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Kahale, South Kivu Province, Democratic Republic of the Congo',
       'Kalehe, South Kivu Province, Democratic Republic of the Congo',
       'Kirumba, North Kivu Province, Democratic Republic of the Congo',
       'Lake Kivu, DRC Congo', 'Lake Kivu, Democratic Republic of Congo',
       'South Kivu Province, Democratic Republic of the Congo',
       'South Kivu Province, the Democratic Republic of the Congo',
       'South Kivu growing region, Democratic Republic of the Congo',
       'South Kivu, Democratic Republic of the Congo'], 'Democratic Republic of the Congo'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Dipilto, Nicaragua', 'Jinotega Department, Nicaragua',
       'Jinotega, Nicaragua',
       'La Dalia, Matagalpa Department, northern Nicaragua',
       'La Fundadora, Jinotega, Nicaragua',
       'La Providencia, Jalapa, Nicaragua',
       'Matagalpa growing region, Nicaragua', 'Matagalpa, Nicaragua',
       'Nueva Segovia Department, Nicaragua',
       'Nueva Segovia growing region, Nicaragua',
       'Nueva Segovia, Nicaragua'], 'Nicaragua'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Chiang Rai Province, Thailand',
       'Chiang Rai Province, northern Thailand',
       'Doi Pangkhon growing region, northern Thailand',
       'Doi Pangkhon, Thailand', 'Huai Mae Liam, Chiang Rai, Thailand',
       'Nan Province, Thailand', 'Northern Thailand',
       'Omkoi District, Chiang Mai Province, Thailand',
       'Tha Sae, Chumphon, Thailand'], 'Thailand'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Cau Dat, southwest Vietnam', 'Dalat, Vietnam',
       'Lam Dong Province, Vietnam'], 'Vietnam'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Chaguites, Honduras',
       'Copan, Honduras', 'Corquin, Honduras', 'El Soccoro, Honduras',
       'El Socorro, Comayagua Department, Honduras', 'Honduras',
       'La Paz, Honduras', 'Las Flores, Honduras',
       'Los Planes, Comayagua, Honduras',
       'Marcala growing region, La Paz Department, Honduras',
       'Marcala, Honduras', 'Marcala, La Paz Department, Honduras',
       'Masaguara, Intibucá Department, Honduras',
       'Ocotepeque Department, Honduras', 'San Jose, La Paz, Honduras',
       'San José, La Paz Department, Honduras',
       'Santa Barbara Department, Honduras', 'Santa Barbara, Honduras',
       'Santa Bárbara, Honduras', 'Santa Elena, Honduras',
       'Santa Elena, La Paz, Honduras',
       'Siguatepeque, Comayagua Department, Honduras',
       'Tres Cruces, Lempira Department, Honduras'], 'Honduras'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Chinchipe, Zamora Province, south-eastern Ecuador',
       'Chito, Zamora Chinchipe, Ecuador',
       'Conganama, Loja Province, Ecuador',
       'Congonama, Loja region, Ecuador', 'Congonama, Loja, Ecuador',
       'Ibarra, Imbabura Province, Ecuador',
       'Isla Santa Cruz and Isla San Cristóbal, Galapagos Islands, Ecuador',
       'Loja Province, southern Ecuador',
       'Pallatanga, Chimborazo Province, Ecuador',
       'Pallatanga, Chimborazo, Ecuador', 'Pichincha Province, Ecuador',
       'Pichincha Province, north-central Ecuador',
       'Pichincha growing region, northern Ecuador',
       'Pichincha, northern Ecuador', 'Pinchincha, Ecuador',
       'Quilanga, Ecuador', 'Quito, Pichincha Province, Ecuador',
       'San Jose de Minas, Pichincha, Ecuador',
       'San José de Minas, Pichincha Province, Ecuador',
       'San Lorenzo, Saraguro, Loja, Ecuador',
       'Santa Elena Province, Ecuador', 'Saraguro, Loja, Ecuador'], 'Ecuador'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Caranavi Province, La Paz Department, west-central Bolivia',
       'Caranavi, Bolivia'], 'Bolivia'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Captain Cook, North Kona growing district, “Big Island” of Hawaii',
       'Holualoa, North Kona growing district, “Big Island” of Hawaii',
       "Ka'u growing region, Big Island of Hawaii",
       'Kalaheo, Kauai, Hawaii', 'Kealakekua, Kona, Big Island of Hawaii',
       'Kona growing district, Big Island of Hawaii', 'Kona, Hawaii',
       'Maunawili growing region, southeastern Oahu, Hawaii',
       'North Kona growing district, “Big Island” of Hawaii', 'Holualoa, Kona growing region, Big Island of Hawai’i',
       'Holualoa, Kona, Big Island of Hawai’i',
       "Holualoa, North Kona growing district, “Big Island” of Hawai'i",
       'Holualoa, North Kona growing district, “Big Island” of Hawai’i',
       'Holualoa, North Kona, Big Island of Hawai’i',
       "Ka'u District, Big Island of Hawai’i",
       'Ka\'u growing district, "Big Island" of Hawai’i',
       "Ka'u growing region, Big Island of Hawai'i",
       'Kainaliu, Kona District, Big Island of Hawai’i',
       'Kainaliu, Kona, Big Island of Hawai’i',
       'Ka‘ū growing region, Big Island of Hawai’i',
       'Ka‘ū, Big Island of Hawai‘i', 'Ka‘ū, Big Island of Hawai’i',
       "Ka’u growing region, Big Island of Hawai'i",
       'Ka’u growing region, Big Island of Hawai’i',
       'Ka’u growing region, Big island of Hawai’i',
       'Ka’u, Big Island of Hawai’i',
       "Kealakekua, Kona growing district, Big Island of Hawai'i",
       "Kona District, Kealakekua growing region, Big Island of Hawai'i",
       "Kona growing district, Big Island of Hawai'i",
       "Kona growing region, Big Island of Hawai'i",
       'Kona growing region, Big Island of Hawai’i',
       'Kona growing region, “Big Island” of Hawai’i',
       'Kona, Big Island of Hawai’i', "Kula, Island of Maui, Hawai'i",
       'Kurtistown, Puna, “Big Island” of Hawai’i',
       'North Kona growing district, “Big Island” of Hawai’i',
       "Puna District, Big Island of Hawai'i",
       'Puna growing region, Big Island of Hawai’i',
       'Puna, Big Island of Hawai’i',
       'South Kona growing region, Hawai’i',
       'Volcano, Puna District, Big Island of Hawai’i',
       'Wood Valley, Ka’u, Big Island of Hawai’i'], 'Hawaii'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Cap Haitien, Haiti', 'Central Plateau, Blue Pine Forest, Haiti',
       'Dondon, Haiti', 'Savane Zombie, Haiti', 'Thiotte, Haiti'], 'Haiti'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Bungoma region, western Kenya', 'Bungoma, Kenya', 'Central Kenya',
       'Central Province, Kenya', 'Embu County, Eastern Province Kenya',
       'Embu County, Eastern Province, Kenya', 'Embu County, Kenya',
       'Embu, Kenya', 'Gatundu, Thika Province, central Kenya',
       'Gichugu Division, Kirinyaga County, central Kenya',
       'Karundu, Nyeri County, Kenya', 'Kenya', 'Kenya Gatugi AB',
       'Kericho County, Kenya',
       'Kericho County, Rift Valley region, Kenya',
       'Kiambi County, Kenya', 'Kiambu County, Kenya',
       'Kiambu County, south-central Kenya',
       'Kiambu growing region, south-central Kenya',
       'Kibugu Village, Embu County, Kenya', 'Kirinyaga County, Kenya',
       'Kirinyaga County, south-central Kenya',
       'Kirinyaga District, south-central Kenya', 'Kirinyaga, Kenya',
       'Kisii, southwestern Kenya',
       'Mathira West District, Nyeri County, Kenya',
       'Mathira West District, Nyeri growing region, Kenya',
       'Mount Kenya growing region, Kenya',
       'Mukaro, Nyeri growing region, south-central Kenya',
       "Murang'a County, central Kenya",
       'Muranga County, South-Central Kenya',
       'Muranga District, Central Province, Kenya',
       'Muranga District, central Kenya', 'Nakuru County, Kenya',
       'Nakuru County, south-central Kenya',
       'Nakuru Province, south-central Kenya',
       'Ngiriambu District, Kenya', 'Nyeri County, Kenya',
       'Nyeri County, south-central Kenya', 'Nyeri growing region, Kenya',
       'Nyeri growing region, south-central Kenya', 'South-central Kenya',
       'Thika Plateau, Central Highlands, Kenya',
       'Thika growing region, central Kenya',
       'iambu growing region, south-central Kenya',
       'yeri growing region, south-central Kenya'], 'Kenya'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Buhoma, southwest Uganda',
       'Kapchorwa District, Eastern Region, Uganda',
       'Sipi Falls, Bugisu Region, Uganda'], 'Uganda'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Boneza, Rwanda', 'Central Rwanda', 'Western Province, Rwanda',
       'Gakenke District, Northern Province, Rwanda',
       'Gakenke growing region, Rwanda',
       'Gakenke, Northern Province, Rwanda', 'Gakenke, Rwanda',
       'Gikongoro Prefecture, south-central Rwanda',
       'Huye District, Rwanda', 'Huye District, southern Rwanda',
       'Karongi District, Western Province, Rwanda',
       'Karongi District, western Rwanda',
       'Muhanga District, Southern Province, Rwanda', 'Muhanga, Rwanda',
       'Musasa, Rwanda', 'Namasheke District, Western Province, Rwanda',
       'Northern Province, Rulindo District, Rwanda',
       'Northern Province, Rwanda', 'Nyakibanda, Huye, Rwanda',
       'Nyamagabe District, Southern Province, Rwanda',
       'Nyamagabe district, Southern Province, Rwanda',
       'Nyamasheke District, Lake Kivu, Rwanda',
       'Nyamasheke District, Rwanda',
       'Nyamasheke District, Western Province, Rwanda',
       'Nyamasheke, Rwanda', 'Nyaruguru District, Rwanda',
       'Rulindo, Rwanda', 'Rustiro District, Western Province, Rwanda',
       'Rutsiro District, western Rwanda',
       'Rutsiro, Western Province, Rwanda'], 'Rwanda'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Buhinyuza District, Muhinga Province, Burundi',
       'Buhinyuza District, Muyinga Province, Burundi', 'Burundi',
       'Bururi growing region, Burundi', 'Buyenzi, Katanga, Burundi',
       'Gitega Province, Burundi', 'Kayanza Province, Burundi',
       'Kayanza Province, northern Burundi', 'Kayanza State, Burundi',
       'Kayanza, Burundi', 'Kayanza, Kabuye, Burundi',
       'Kayanza, Northern Province, Burundi',
       'Murutra, Kayanza Province, Burundi', 'Ngozi Province, Burundi',
       'Northern Burundi', 'Northern Province, Burundi'], 'Burundi'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Bella Vista, Chiapas, Mexico', 'Chiapas State, Mexico',
       'Chiapas, Mexico', 'Coatepec, Veracruz State, Mexico',
       'Guerrero State, Mexico', 'La Cañada, Oaxaca, Mexico',
       'Las Margaritas, Chiapas State, Mexico',
       'Los Altos, Chiapas State, Mexico',
       'Motozintla de Mendoza, Chiapas State, Mexico', 'Nyarita, Mexico',
       'Oaxaca State, Mexico', 'Oaxaca, Mexico',
       'Pluma Hidalgo, Oaxaca State, Mexico',
       'Sierra Madre, Chiapas State, Mexico',
       'Sierra Madre, Chiapas, Mexico', 'Tlaltetela, Veracruz, Mexico',
       'Veracruz, Mexico', 'Yautepec, Miahuatlán, Oaxaca State, Mexico',
       'Yautepec/Miahuatlan, Oaxaca State, Mexico'], 'Mexico'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Banz, Jiwaka Province, Papua New Guinea',
       'Eastern Highlands, Papua New Guinea',
       'Eastern Highlands,Papua New Guinea',
       'Kabiufa, Eastern Highlands, Papua New Guinea',
       'Kainantu District, Eastern Highlands Province, Papua New Guinea',
       'Purosa Village, Eastern Highlands, Papua New Guinea',
       'Upper Waghi Valley, Jiawaka Province, Papua New Guinea',
       'Western Highlands Province, Papua New Guinea',
       'Western Highlands, Papua New Guinea',
       'ainantu District, Eastern Highlands Province, Papua New Guinea'], 'Papua New Guinea'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Arusha Region, northern Tanzania', 'Karatu, Tanzania',
       'Mara growing region, Tarime, Tanzania', 'Mbeya, Tanzania',
       'Mbozi, Mbeya growing region, southwestern Tanzania',
       'Ngila Estate, Ngorongoro Conservation Area, Tanzania',
       'Ngorogoro, Tanzania',
       'Ngorongoro Crater region, northern Tanzania',
       'Ngorongoro, Tanzania', 'Songwe Region, Mbozi District, Tanzania',
       'Songwe Region, southwestern Tanzania', 'Tanzania',
       'Tarime District, Mara Region, Tanzania'], 'Tanzania'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Atok, Benguet, The Philippines',
       'Belis, Atok, Benguet Province, Philippines',
       'Benguet Province, The Philippines', 'Benguet, Philippines'], 'Philippines'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Amaybamba, Cusco, Peru', 'Cajamarca growing region, Peru',
       'Cajamarca region, Peru', 'Cajamarca region, northern Peru',
       'Cajamarca, Peru', 'Chirinos, Cajamarca Region, Peru',
       'Chirinos, San Ignacio Province, Peru',
       'Cusco Department, La Convención Province, Santa Teresa District, Peru',
       'Cusco Province, Peru', 'Cusco Region, Peru', 'Cusco, Peru',
       'El Diamante, Jaén, Peru',
       'El Diamante, San Ignacio, Cajamarca Department, Peru',
       'Huabal, Peru',
       'Huarango, San Ignacio, Cajamarca growing region, Peru',
       'Jaen, Cajamarca, Peru', 'Jaén Province, Cajamarca Region, Peru',
       'Jaén Province, Cajamarca Region, northern Peru', 'Junin, Peru',
       'Junín Province, Peru', 'La Coipa, Cajamarca, Peru',
       'Llayla District, Satipo Province, Peru',
       'Pacaybamba growing region, Peru',
       'Panchia, Tabaconas, Cajamarca Department, Peru',
       'Panchia, Tabaconas, Cajamarca Region, Peru',
       'Pasco Department, Villa Rica, Peru',
       'Pasco growing region, Oxapampa, Peru',
       'Puno, Sandia Valley, Peru',
       'San Ignacio Province, Cajamarca Region, northern Peru',
       'San Ignacio, Cajamarca Region, Peru',
       'San Ignacio, northern Peru',
       'Satipo Province, Junin Region, central Peru',
       'Utcubamba Province, Amazonas Region, north-central Peru',
       'Utcubamba Province, Amazonas region, northern Peru',
       'Villa Rica District, Pasco Department, Peru',
       'Villa Rica, Oxampampa, Pasco Department, Peru',
       'Villa Rica, Oxapampa Province, Peru'], 'Peru'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Alajuela, Costa Rica', 'Biollet, Costa Rica',
       'Biolley, southern Costa Rica', 'Brunca Region, Costa Rica',
       'Brunca growing region, Costa Rica', 'Brunca, Costa Rica',
       'Canton de Desamparados, San Jose, Costa Rica',
       'Carrillos Alto de Poás, Alajuela Province, Costa Rica',
       'Central Valley, Costa Rica', 'Copey District, Costa Rica',
       'Costa Rica', 'Coto Brus, Puntarenas, Costa Rica',
       'Dota, Tarrazú growing region, Costa Rica',
       'El Guarco, Cartago Province, Costa Rica',
       'La Piedra de Rivas, Chirripó, Costa Rica',
       'Llano Bonito de Narajo, Alajuela Province, Costa Rica',
       'Llano Bonito, Naranjo, Costa Rica', 'Tarrazu, Costa RIca',
       'Los Angeles, Sabanilla de Alajuela, Costa Rica',
       'Los Santos, Tarrazú, Costa Rica',
       'Lourdes de Naranjo, West Valley, Costa Rica',
       'Mercedes Sur, Turrubares, San José Province, Costa Rica',
       'Monteverde, Costa Rica', 'Naranjo, Central Valley, Costa Rica',
       'Naranjo, West Valley, Costa Rica',
       'Poás Volcano region, Alajuela Province, Costa Rica',
       'Poás Volcano region, central Costa Rica',
       'Rivas District, Chirripo Region, Costa Rica',
       'Rosario de Desamparados, Tarrazú, Costa Rica',
       'Sabanilla de Alajuela growing region, Costa Rica',
       'Sabanilla de Alajuela, Central Valley, Costa Rica',
       'Sabanilla de Alajuela, Costa Rica',
       'San Vito, Puntarenas Province, Costa Rica',
       'Santa Maria de Dota, Costa Rica',
       'Santa Maria de Dota, Tarrazu growing region, Costa Rica',
       'Tarrazu growing region, Costa Rica', 'Tarrazu, Costa Rica',
       'Tarrazú growing region, Costa Rica', 'Tarrazú, Costa Rica',
       'Tobosi, Cartago Province, Costa Rica', 'West Valley, Costa Rica'], 'Costa Rica'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Alto Caparaó, Minas Gerais State, Brazil', 'Bahia, Brazil',
       'Brazil', 'Brazil and four other origins',
       'Campestre, Minas Gerais State, Brazil',
       'Campos Alto district, Minas Gerais State, southeastern Brazil',
       'Carmo de Minas growing region, northeastern Minas Gerais State, Brazil',
       'Cerrado Mineiro growing region, Santa Luzia, Brazil',
       'Cerrado Mineiro, Brazil', 'Cerrado growing region, Brazil',
       'Chapada Diamantina growing region, Bahia State, Brazil',
       'Chapada Diamantina region, Bahia State, Brazil',
       'Ibicoara Municipality, Chapada Diamantina region, Bahia State, Brazil',
       'Ipanema, Brazil',
       'Mantiqueira de Minas growing region, southern Minas Gerais State, Brazil',
       'Matas de Minas growing region, eastern Minas Gerais State, Brazil', 'Minas Gerais State, Brazil',
       'Minas Gerais State, southeastern Brazil',
       'Mogiana growing region, Sao Paulo State, Brazil',
       'Santo Antônio do Amparo, Minas Gerais State, Brazil',
       'Serra da Mantiqueira, Brazil',
       'Southern Minas Gerais State, southeastern Brazil',
       'Sul de Minas growing region, Minas Gerais State, Brazil',
       'São Sebastião da Grama, Sul de Minas, Brazil',
       'São Sebastião da Grama, São Paulo state, south-central Brazil',
       'São Sebastião de Grama, Brazil',
       'Vale da Grama, Minas Gerais State, Brazil',
       'Vale de Grama, Mogiana, Brazil'], 'Brazil'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Ahuachapan, El Salvador', 'Alotepec-Metapan region, El Salvador',
       'Apaneca, Ahuachapán Department, El Salvador',
       'Apaneca, El Salvador','Apaneca Ilamatepec mountain range',
       'Apaneca-Ilamatepec Mountain Range, El Salvador',
       'Apaneca-Ilamatepec growing region, El Salvador',
       'Apaneca-Ilamatepec, El Salvador',
       'Calzontes Arriba, Santa Ana Department, El Salvador',
       'Canton Lomas de San Marcelino, Coatepeque, Santa Ana, El Salvador',
       'Cantón El Tunel, La Palma, Chalatenango, El Salvador',
       'Cerro El Tigre, El Salvador',
       'Chalatenango Department, El Salvador',
       'Chalatenango Department, northwestern El Salvador',
       'Chalatenango growing region, northwest El Salvador',
       'Chalatenango, El Salvador', 'Costa Rica, El Salvador',
       'El Boquerón growing region, El Salvador', 'El Salvador',
       'La Palma, Chalatenango Department, northwestern El Salvador',
       'Los Naranjos, Juayua, Sonsonate, El Salvador',
       'Metapan, El Salvador',
       'Monte Verde, Santa Ana Department, central El Salvador',
       'Santa Ana Department, El Salvador',
       'Santa Ana Department, northwestern El Salvador',
       'Santa Ana region, El Salvador',
       'Santa Rosa, La Unión Department, El Salvador',
       'Tecapa Chinameca growing region, El Salvador',
       'Tecapa Chinameca growing region, Santiago de María, southeastern El Salvador',
       'Tecapa Chinameca growing region, southeastern El Salvador',
       'antón Montañita, Volcán Santa Ana, El Salvador'], 'El Salvador'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Alto Jaramillo, Boquete growing region, western Panama',
       'Alto Quiel, Boquete growing region, western Panama',
       'Alto Quiel, Panama', 'Boquete growing region, Panama',
       'Boquete growing region, western Panama', 'Boquete, Panama',
       'Cañas Verdes, Boquete growing region, Panama',
       'Chiriqui Province, Panama',
       'Chiriqui Province, far western Panama',
       'Chiriqui Province, western Panama',
       'Chiriqui growing region, Panama',
       'Chiriqui, Boquete growing region, western Panama',
       'Chiriquí Province, Panama', 'Chiriquí, Panama',
       'Finca Santa Teresa, Volcan, Panama',
       'Horcheta, Chiriqui Province, western Panama',
       'Horqueta, Chiriquí, Boquete, Panama',
       'Jaramillo, Boquete growing region, Panama',
       'Jaramillo, Boquete growing region, western Panama',
       'Jaramillo, Panama', 'Jurutungo, Renacimiento, Panama',
       'Nueva Suiza, Chiriquí, Panama',
       'Paso Ancho, Volcan, western Panama',
       'Piedra Candela, Chiriqui Province, far western Panama',
       'Piedra Candela, Chiriqui Province, western Panama',
       'Potrerillo Arriba, Boquete, Panama',
       'Renacimiento District, Chiriquí Province, Panama',
       'Tierras Altas, Chiriquí Province, Panama',
       'Volcan growing region, western Panama', 'Volcan, Panama',
       'Volcán growing region, Chiriquí Province, Panama'], 'Panama'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Alishan Township, Chiayi County, Taiwan',
       'Alishan, Chaiyi, Taiwan', 'Alishan, Chia-Yi City, Taiwan',
       'Alishan, Chia-Yi, Taiwan', 'Alishan, Taiwan', 'Pingtung, Taiwan',
       'Sun Moon Lake, Taiwan', 'Taitung Luan Mountain, Taiwan', 'Taiwan',
       'Yunlin, Taiwan'], 'Taiwan'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Acevedo, Huila Department, Colombia',
       'Algeciras, Huila Department, Colombia',
       'Algeciras, Huila, Colombia', 'Antioquia Department, Colombia',
       'Antioquia Department, northwest Colombia', 'Antioquia, Colombia',
       'Antoquia, Colombia', 'Aratoca, Santander Department, Colombia',
       'Armenia, Quindio Department, Colombia',
       'Buesaco, Nariño Department, Colombia',
       'Caicedo, Antioquia Department, Colombia',
       'Caicedonia, Valle de Cauca Department, Colombia',
       'Caicedonia, Valle del Cauca Department, Colombia',
       'Caldas Department, Colombia', 'Caldas growing region, Colombia',
       'Caldas, Colombia', 'Cauca Department, Colombia',
       'Cauca, Colombia', 'Chinas, San Agustín, Huila, Colombia',
       'Colombia', 'Concordia, Colombia',
       'Cundinamarca Department, Colombia',
       'Cundinamarca Department, central Colombia',
       'Cundinamarca, Colombia', 'Dolores, Tolima Department, Colombia',
       'Fredonia, Antioquia Department, Colombia',
       'Gaitania, Tolima Department, west-central Colombia',
       'Giraldo, Antioquia, Colombia', 'Huila Colombia',
       'Huila Department, Colombia',
       'Huila Department, southern Colombia',
       'Huila Department, southwestern Colombia', 'Huila, Colombia',
       'Inza, Cauca Department, Colombia', 'Kenya, Colombia',
       'La Argentina, Huila Department, Colombia',
       'La Mesa, Cundinamarca, Colombia', 'La Union, Nariño, Colombia',
       'Liboriana Valley, Antioquia Department, Colombia',
       'Los Naranjos, La Argentina, Huila Department, Colombia',
       'Narino Department, southern Colombia',
       'Nariño Department, Colombia',
       'Nariño Department, southern Colombia',
       'Nariño Department, southwestern ColombiaNar',
       'Nariño region, Antioquia Department, Colombia',
       'Nariño, Colombia', 'Neira, Caldas Department, Colombia',
       'Paez region, Cauca Department, Colombia',
       'Palestina region, Huila Department, Colombia',
       'Palestina, Huila, Colombia', 'Pasto, Nariño Department, Colombia',
       'Paéz, Cauca Department, Colombia',
       'Piendamó, Cauca Department, Colombia',
       'Pijao, Quindio Department, Colombia',
       'Pitalito Municipality, Huila Department, Colombia',
       'Pitalito growing region, Huila Department, Colombia',
       'Pitalito, Huila Department, Colombia',
       'Pitalito-Bruselas, Huila Department, Colombia',
       'Planadas, Tolima Department, Colombia',
       'Planadas, Tolima, Colombia',
       'Planadas, southern Tolima growing region, Colombia',
       'Quindio Department, Colombia', 'Quindío Department, Colombia',
       'Risaralda Department, Colombia',
       'Risaralda, Caldas Department, Colombia', 'Risaralda, Colombia',
       'Salgar Municipality, Antioquia Department, west-central Colombia',
       'San Agustín growing region, Huila Department, Colombia',
       'San Augustin, Huila, Colombia',
       'San Augustín, Huila Department, Colombia',
       'San Isidro, Acevedo, Huila, Colombia',
       'San José, Caldas, Colombia',
       'Santa Barbara, Antioquia Department, Colombia',
       'Santa Bárbara, Antioquia Department, Colombia',
       'Santa Maria, Colombia', 'Santander Department, Colombia',
       'Santander, Colombia', 'Sevilla, San Augustin, Huila, Colombia',
       'Southern Tolima Department, west-central Colombia',
       'Suaza, Huila, Colombia', 'Tolima Department, Colombia',
       'Tolima Department, center-west Colombia', 'Tolima, Colombia',
       'Trujillo, Valle del Cauca Department, Colombia',
       'Trujillo, Valle del Cauca, Colombia',
       'Urrao, Antioquia Department, Colombia',
       'Valle de Cauca Department, Colombia', 'Valle de Cauca, Colombia',
       'Valle del Cauca Department, Colombia',
       'Valle del Cauca Department, western Colombia',
       'Valle del Cauca growing region, Colombia',
       'Vereda Santa Rita, Manizales, Caldas, Colombia',
       'Vereda, Huila Province, Colombia'], 'Colombia'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Al Hayma District, Sana’a Governorate, Yemen',
       'Al Hayma growing region, Al Kharijiyah District, Sana’a Governorate, Yemen',
       'Al Hayma region, Sana’a Governorate, Yemen',
       'Al Mahjr, Al Hayma District, Yemen',
       'Al Mashtal ul Burhani, Yemen',
       'Al Wadi region, Sana’a Governorate, Yemen',
       'Al-Durrar, Sana’a Governorate, Yemen', 'Al-Haimah, Yemen',
       'Bani Matar growing region, Yemen',
       'Bani Matar, Sana’a Governorate, Yemen', 'Central Yemen',
       'Haraaz growing region, Yemen', 'Haraaz, Yemen',
       'Haraz growing region, north-central Yemen',
       'Hayma Dakhiliya growing region, Sana’a Governorate, Yemen',
       'Jabal Haraz, Sana’a Governorate, Yemen',
       'Sana’a Governorate, Yemen', 'Sana’a growing region, Yemen',
       'Sa’dah Governorate, Yemen', 'Sharqi, Haraaz, Yemen'], 'Yemen'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Aceh Province, Sumatra', 'Aceh, Sumatra',
        'Aceh Province, Sumatra, Indonesia',
       'Aceh Province, northern Sumatra Indonesia',
       'Aceh Province, northern Sumatra, Indonesia',
       'Aceh growing region, Aceh Province, northern Sumatra, Indonesia',
       'Aceh, Sumatra, Indonesia', 'Bali, Indonesia',
       'Bebesen District, Aceh Tengah, Sumatra, Indonesia',
       'Flores Island, Indonesia',
       'Gayo (also Aceh) growing region, Aceh Province, northern Sumatra, Indonesia',
       'Gunung Tujuh, Kerinci, Sumatra, Indonesia',
       'Jambi Province, Sumatra, Indonesia',
       'Java, Flores and Sumatra, Indonesia',
       'Kerinci Highlands, Jambi Province, Sumatra, Indonesia',
       'Lintong growing region, North Sumatra Province, Indonesia',
       'Lintong growing region, Sumatra, Indonesia',
       'Lintong growing region, northern Sumatra, Indonesia',
       'Lintongnihuta, northern Sumatra, Indonesia',
       'Mandheling growing region, northern Sumatra, Indonesia',
       'Mount Kerinci Highlands, Sumatra, Indonesia',
       'Northern Sumatra, Indonesia',
       'Pantan Musara, Gayo, Sumatra, Indonesia',
       'Pematang Purba, Simalungun, Sumatra, Indonesia',
       'Simalungun Regency, North Sumatra Province, Sumatra, Indonesia',
       'Simalungun, Sumatra, Indonesia', 'Sumatra, Indonesia',
       'Toraja growing region, south-central Sulawesi, Indonesia',
       'West Java, Indonesia'], 'Indonesia'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Agaro District, Jimma Zone, west-central Ethiopia',
       'Agaro Gera, Jimma Zone, Oromia Region, Ethiopia',
       'Agaro Gera, Jimma Zone, Oromia State, Ethiopia',
       'Alaka District, Guji Zone, Oromia region, southern Ethiopia',
       'Aleta Wondo, Sidama (also Sidamo) growing region, southern Ethiopia',
       'Amhara Region, Ethiopia', 'Gedeb District, Gedeo Zone, southern',
       'Arbegona, Sidama (also Sidamo) growing region, south-central Ethiopia',
       'Arbegona, Sidama Region, Ethiopia', 'Worka-Sakaro, Gedeb District, Gedeo Zone',
       'Banti Nenga, Oromia Region, Ethiopia', 
       'Bench Maji Zone, southwestern Ethiopia',
       'Bench-Maji Zone, Southern Ethiopia',
       'Bench-Maji Zone, southern Ethiopia',
       'Bita Genet District, Keffa Zone, southwestern Ethiopia',
       'Bombe Mountains, Sidama growing region, Ethiopia',
       'Bombe Village, Bensa District, Sidamo growing region, Ethiopia',
       'Bombe mountains, Sidama Region, southern Ethiopia',
       'Bona Zuria, Sidama Region, Ethiopia',
       'Chelchele, Gedeb District, Gedeo Zone, Ethiopia',
       'Djimma growing region, Oromia State, Ethiopia',
       'Djimma, Ethiopia', 'Djimmah, Oromia Region, Ethiopia', 'Ethiopia',
       'Ethiopia Natural Yirgacheffe Adado Shara', 'Ethiopia, Burundi',
       'Ethiopia, Colombia, Kenya', 'Ethiopia, Indonesia',
       'Gedeb District, Gedeo Zone, Ethiopia',
       'Gedeb District, Gedeo Zone, southern Ethiopia',
       'Gedeb District, Yirgacheffe growing region, south-central Ethiopia',
       'Gedeo Zone, Kochere, Ethiopia',
       'Gedeo Zone, SNNP Region, southern Ethiopia',
       'Gedeo Zone, Yirgacheffe growing region, southern EthiopiaGedeo Zone, southern Ethiopia',
       'Gedeo Zone, southern Ethiopia',
       'Gedeo, Yirgacheffe growing region, south-central Ethiopia',
       'Gerbicho Rogicha, Bule Hora District, Guji Zone, Oromia Region, Ethiopia',
       'Guji Zone, Borena Hagermariam District, Ethiopia',
       'Guji Zone, Ethiopia', 'Guji Zone, Oromia Region, Ethiopia',
       'Guji Zone, Oromia Region, Hambela Woreda, Ethiopia',
       'Guji Zone, Oromia Region, Southern Ethiopia',
       'Guji Zone, Oromia Region, south-central Ethiopia',
       'Guji Zone, Oromia Region, southern Ethiopia',
       'Guji Zone, Oromia region, southern Ethiopia',
       'Guji Zone, southern Ethiopia', 'Hambela Dimtu, Guji, Ethiopia',
       'Hambela District, Guji Zone, Oromia Region, southern Ethiopia',
       'Hambela Wamena District, Guji Zone, Ethiopia',
       'Hambela Wamena District, Guji Zone, Oromia Region, southern Ethiopia',
       'Hambela Wamena District, Guji Zone, Oromia region, southern Ethiopia',
       'Hambela Wamena, Guji Zone, Oromia, Ethiopia',
       'Hambela district, Oromia growing region, southern Ethiopia',
       'Harar (also Harrar) growing region of eastern Ethiopia',
       'Hayisa Village, Bure Woreda, Sidama Zone, Ethiopia',
       'Illubabor Zone, Oromia Region, Ethiopia',
       'India, Brazil, Ethiopia, Indonesia, Colombia',
       'Jimma Zone, Oromia State, Ethiopia',
       'Jimma growing region, southern Ethiopia',
       'Kebele Buku Sayisa, Guji Zone, Oromia region, Ethiopia',
       'Keramo Village, Sidama Region, Ethiopia',
       'Kochere District, Gedeo Zone, Ethiopia',
       'Kochere Woreda, Gedeo Zone, southern Ethiopia',
       'Kochere Woreda, Yirgacheffe growing region, south-central Ethiopia',
       'Kochere, Yirgacheffe growing region, Ethiopia',
       'Kochere, Yirgacheffe growing region, south-central Ethiopia',
       'Konga Village, Gedeo Zone, Ethiopia',
       'Limu Woreda, Oromia region, southwest Ethiopia',
       'Limu growing region, southwest Ethiopia',
       'Mirado Village, Bensa District, Sidama Zone, Ethiopia',
       'Nensebo Woreda, Sidama, Ethiopia',
       'Odo Shakiso District, Guji Zone, Oromia Region, southern Ethiopia',
       'Odo Shakiso District, Guji Zone, Oromia region, southern Ethiopia',
       'Odo Shakiso District, Guji Zone, southern Ethiopia',
       'Odo Shakiso District, Western Guji, Ethiopia',
       'Oromia Region, Jimma Zone, Ethiopia',
       'Oromia Region, southern Ethiopia',
       'Oromia growing region, southern Ethiopia',
       'Oromia region, southwest Ethiopia', 'Oromia, southern Ethiopia',
       'Sama, Ana Sora District, Oromia Region, Ethiopia',
       'Shakiso District, Guji Zone, southern Ethiopia',
       'Sidama (also Sidamo) growing region, south-central Ethiopia',
       'Sidama (also Sidamo) growing region, southern Ethiopia',
       'Sidama (also Sidamo) region, Ethiopia', 'Sidama Region, Ethiopia',
       'Sidama Region, south-central Ethiopia',
       'Sidama Zone, Oromia Region, Ethiopia',
       'Sidama growing region, Ethiopia',
       'Sidama growing region, southern Ethiopia',
       'Sidamo (also Sidama) growing region, south-central Ethiopia',
       'Sidamo (also Sidama) growing region, southern Ethiopia',
       'Sidamo (also Sidama), Ethiopia',
       'Sidamo Zone, Oromia Region, Ethiopia',
       'Sidamo growing region, Ethiopia',
       'Sidamo growing region, south-central Ethiopia',
       'Sidamo growing region, southern Ethiopia', 'Sidamo, Ethiopia',
       'Southern Ethiopia',
       'Tore Village, Yirgacheffe growing region, southern Ethiopia',
       'Uraga District, Guji Zone, Ethiopia',
       'Uraga, Guji Zone, Ethiopia',
       'Uraga, Guji Zone, Oromia Region, Southern Ethiopia',
       'Wenango District, Gedeo Zone, Ethiopia',
       'West Guji Zone, Hambela Wamena Woreda, Ethiopia',
       'West Guji Zone, Oromia Region, southeastern Ethiopia',
       'West Guji Zone, Oromia Region, southern Ethiopia',
       'Worka Chelbessa, Gedeb, Ethiopia',
       'Worka-Sakaro, Gedeb District, Gedeo Zone, Ethiopia',
       'Yirgacheffe growing region, Ethiopia',
       'Yirgacheffe growing region, south-Central Ethiopia',
       'Yirgacheffe growing region, south-central Ethiopia',
       'Yirgacheffe growing region, southern Ethiopia',
       'Yirgacheffe, southern Ethiopia',
       'Yirgachefffe growing region, southern Ethiopia',
       'idamo (also Sidama) growing region, south-central Ethiopia',
       'idamo (also Sidama) growing region, southern Ethiopia',
       'ochere Woreda, Gedeo Zone, Ethiopia'], 'Ethiopia'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Acatenango Valley, Guatemala',
       'Acatenango growing region, Guatemala',
       'Acatenango growing region, central Guatemala',
       'Acatenango, Chimaltenango Department, Guatemala',
       'Acatenango, Guatemala', 'Alotenango, Antigua, Guatemala',
       'Antigua growing region, Guatemala', 'Antigua, Guatemala',
       'Atitlán growing region, Guatemala',
       'Chimaltenango Department, Guatemala', 'Chimaltenango, Guatemala',
       'Coban, Guatemala',
       'Cobán growing region, Alta Verapaz Department, Guatemala',
       'Cobán growing region, Alta Verapaz, Guatemala',
       'Cobán growing region, central Guatemala',
       'Cobán, Alta Verapaz Department, Guatemala',
       'Concepción Huista, Huehuetenango Department, Guatemala',
       'El Progresso Department, Guatemala',
       'El Progresso, Sierra de las Minas, eastern Guatemala',
       'El Salvador, Guatemala', 'Fraijanes Plateau, Guatemala',
       'Fraijanes growing region, Guatemala',
       'Fraijanes, central Guatemala', 'Guatemala',
       'Huehuetenango Department, Guatemala',
       'Huehuetenango growing region, Guatemala',
       'Huehuetenango, Guatemala', 'Huehuetenengo Department, Guatemala',
       'Jutiapa Department, Guatemala',
       'La Libertad, Huehuetenango Department, Guatemala',
       'La Libertad, Huehuetenango, Guatemala',
       'Lake Amatitlán area, south-central Guatemala',
       'Lake Amatitlán region, south-central Guatemala',
       'Lake Atitlán growing region, Guatemala',
       'New Oriente growing region, Guatemala',
       'Palencia, Fraijanes Plateau growing region, central Guatemala',
       'Palencia, Guatemala', 'Quiché, northern Guatemala',
       'Region Concepción Huista, Huehuetenango growing region, Guatemala',
       'San Cristobal Acasaguastlán, El Progreso Department, Guatemala',
       'San Cristobal Acasaguastlán, El Progreso, Sierra de las Minas, Guatemala',
       'San Cristobal Cucho, San Marcos Department, Guatemala',
       'San Cristobal, Cobán, Alta Verapaz, Guatemala',
       'San Juan La Laguna, Lake Atitlan, Guatemala',
       'San Lucas Tolimán, Lake Atitlán growing region, Guatemala',
       'San Martin Jilotepeque, Chimaltenango Department, Guatemala',
       'San Martin Jilotepeque, Chimaltenango Department, central Guatemala',
       'Santa Barbara, Huehuetenango, Guatemala',
       'Santa Rosa growing region, Guatemala', 'Sololá, Guatemala',
       'Suchitan, Guatemala',
       'Tojquia, Huehuetenango Department, Guatemala',
       'Villa Canales, Guatemala Department, Guatemala'], 'Guatemala'))

# %%
coffee_fix = coffee_fix.replace({'origin_country':{'Bhirkune Village, Nuwakot District, Nepal' : 'Nepal',  
                                           'Blue Mountain growing region, eastern Jamaica.' : 'Jamaica', 
                                           'Coastal southern California' : 'California', 
                                           'Jarabacoa, Dominican Republic' : 'Dominican Republic', 
                                           'Northern Province, Zambia' : 'Zambia', 
                                           'KwaZulu-Natal province, South Africa' : 'Africa'}})

# %%
coffee_fix_test8 = coffee_fix[coffee_fix['origin_count'] == 1]
# coffee_fix_test8 = coffee_fix_test8[coffee_fix_test8['origin_country'].str.contains(r"Africa", na=False)]
coffee_fix_test8['origin_country'].sort_values(ascending=True).unique()
# Out:
# array(['Africa', 'Africa, South America, Central America', 'Bolivia',
#        'Brazil', 'Buenos Aires, Comayagua, Honduras', 'Burundi',
#        'California', 'Central America', 'China', 'Colombia', 'Costa Rica',
#        'Democratic Republic of the Congo', 'Dominican Republic',
#        'Ecuador', 'El Salvador', 'Ethiopia', 'Guatemala', 'Haiti',
#        'Hawaii', 'Honduras', 'Indonesia', 'Jamaica', 'Kenya',
#        'Latin America', 'Madagascar', 'Malaysia', 'Mexico',
#        'Mexico, Ethiopia, Brazil', 'Nepal', 'Nicaragua', 'Not disclosed',
#        'Panama', 'Papua New Guinea', 'Peru', 'Philippines', 'Rwanda',
#        'Sandy Bay Valley, Saint Helena Island', 'South America',
#        'Sumatra', 'Taiwan', 'Tanzania', 'Thailand', 'Uganda', 'Vietnam',
#        'Yemen', 'Yirgacheffe, Sidamo, Huehuetenango', 'Zambia'],
#       dtype=object)

# %%
coffee_fix_test9 = coffee_fix[coffee_fix['origin_count'] > 1]
coffee_fix_test9 = coffee_fix_test9[coffee_fix_test9['origin_country'].str.contains(r"America", na=False)]
coffee_fix_test9['origin_country'].sort_values(ascending=True).unique()
# Out:
# array(['Africa; Central America', 'Africa; Indonesia; South America',
#        'Africa; South America', 'Africa; South America; Central America',
#        'Americas; Indo-Pacific', 'Asia; Africa; Americas',
#        'Central America; Africa', 'Central America; South America',
#        'Central America; South America; Africa',
#        'Central America; South America; Ethiopia',
#        'Central America; South America; Indonesia',
#        'Ethiopia; Central America', 'Ethiopia; Central and South America',
#        'Indonesia; Central and South America',
#        'South America; Central America; Africa',
#        'Thailand; Vietnam; Latin America'], dtype=object)

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].str.replace(
    'Armenia, Quindio Department, Colombia', 'Colombia')

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].str.replace(
    'Sumatra, Indonesia', 'Indonesia')

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].str.replace(
    'Sumatra', 'Indonesia')

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].str.replace(
    'Democratic Republic of the Congo', 'Congo')

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(
    'Yirgacheffe, Sidamo, Huehuetenango', 'Ethiopia; Guatemala')

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].str.replace(
    'Yunnan, China', 'China')

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].str.replace(
    'Central and South America', 'Central America; South America')

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(
    'Yirgacheffe, Ethiopia; Sidamo (also Sidama), Ethiopia', 'Ethiopia')

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].str.replace(',', ';')

# %%
coffee_fix['origin_count'] = coffee_fix['origin_country'].str.count(r'(;)') + 1

# %%
coffee_fix_test10 = coffee_fix[coffee_fix['origin_count'] == 2]
# coffee_fix_test10 = coffee_fix_test10[coffee_fix_test10['origin_country'].str.contains(r"Nicaragua", na=False)]
coffee_fix_test10['origin_country'].sort_values(ascending=True).unique()
# Out:
# array(['Africa; Asia', 'Africa; Asia Pacific', 'Africa; Central America',
#        'Africa; South America', 'Americas; Indo-Pacific',
#        'Brazil; Colombia', 'Brazil; Costa Rica', 'Brazil; East Timor',
#        'Brazil; Ecuador', 'Brazil; El Salvador', 'Brazil; Ethiopia',
#        'Brazil; Guatemala', 'Brazil; Nicaragua', 'Burundi; Colombia',
#        'Central America; Africa', 'Central America; South America',
#        'Colombia; Brazil', 'Colombia; Burundi', 'Colombia; Ethiopia',
#        'Colombia; Guatemala', 'Colombia; Kenya', 'Congo; Ethiopia',
#        'Costa Rica; Ethiopia', 'Costa Rica; Indonesia',
#        'Dominican Republic; Honduras', 'El Salvador; Brazil',
#        'El Salvador; Costa Rica', 'El Salvador; Guatemala',
#        'El Salvador; Indonesia', 'El Salvador; Peru', 'Ethiopia; Brazil',
#        'Ethiopia; Central America', 'Ethiopia; Colombia',
#        'Ethiopia; Congo', 'Ethiopia; Costa Rica',
# ...

# %%
coffee_fix = coffee_fix.replace({'origin_country':{'Nicaragua; Guatemala' : 'Guatemala; Nicaragua', 
                                                   'Kenya; Guatemala' : 'Guatemala; Kenya', 
                                                   'Papua New Guinea; Guatemala' : 'Guatemala; Papua New Guinea'}})

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(
    'Indonesia; El Salvador', 'El Salvador; Indonesia')

# %%
coffee_fix = coffee_fix.replace({'origin_country':{'Colombia; Ethiopia' : 'Ethiopia; Colombia',  
                                           'Congo; Ethiopia' : 'Ethiopia; Congo', 
                                           'Costa Rica; Ethiopia' : 'Ethiopia; Costa Rica', 
                                           'Indonesia; Ethiopia' : 'Ethiopia; Indonesia', 
                                           'Kenya; Ethiopia' : 'Ethiopia; Kenya', 
                                           'Guatemala; Ethiopia' : 'Ethiopia; Guatemala', 
                                           'Nicaragua; Ethiopia' : 'Ethiopia; Nicaragua', 
                                           'Panama; Ethiopia' : 'Ethiopia; Panama', 
                                           'Haiti; Ethiopia' : 'Ethiopia; Haiti', 
                                           'Mexico; Ethiopia' : 'Ethiopia; Mexico', 
                                           'Peru; Ethiopia' : 'Ethiopia; Peru'}})

# %%
coffee_fix = coffee_fix.replace({'origin_country':{'Burundi; Colombia' : 'Colombia; Burundi', 
                                                   'Kenya; Colombia' : 'Colombia; Kenya', 
                                                   'Papua New Guinea; Colombia' : 'Colombia; Papua New Guinea', 
                                                   'Zambia; Colombia' : 'Colombia; Zambia', 
                                                   'Indonesia; Colombia' : 'Colombia; Indonesia'}})

# %%
coffee_fix = coffee_fix.replace({'origin_country':{'Colombia; Brazil' : 'Brazil; Colombia',  
                                           'El Salvador; Brazil' : 'Brazil; El Salvador', 
                                           'Ethiopia; Brazil' : 'Brazil; Ethiopia', 
                                           'Indonesia; Brazil' : 'Brazil; Indonesia'}})

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(
    'Central America; Africa', 'Africa; Central America')

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].str.replace(
    'Americas', 'America')

# %%
coffee_fix_test11 = coffee_fix[coffee_fix['origin_count'] == 3]
# coffee_fix_test11 = coffee_fix_test11[coffee_fix_test11['origin_country'].str.contains(r"Ethiopia", na=False)]
coffee_fix_test11['origin_country'].sort_values(ascending=True).unique()
# Out:
# array(['Africa; Indonesia; South America',
#        'Africa; South America; Central America', 'Asia; Africa; America',
#        'Brazil; Bali; Ethiopia', 'Brazil; Colombia; Ethiopia',
#        'Brazil; Colombia; Guatemala', 'Brazil; Colombia; Indonesia',
#        'Brazil; Colombia; Kenya', 'Brazil; Costa Rica; Ethiopia',
#        'Brazil; Costa Rica; Guatemala', 'Brazil; Costa Rica; Indonesia',
#        'Brazil; Ecuador; Peru', 'Brazil; Ethiopia; Guatemala',
#        'Brazil; Ethiopia; Honduras', 'Brazil; Ethiopia; Kenya',
#        'Brazil; Ethiopia; Mexico', 'Brazil; Guatemala; India',
#        'Brazil; Guatemala; Indonesia', 'Brazil; Guatemala; Kenya',
#        'Brazil; Guatemala; Nicaragua', 'Brazil; Honduras; Yemen',
#        'Brazil; Indonesia; Panama', 'Brazil; Indonesia; Papua New Guinea',
#        'Buenos Aires; Comayagua; Honduras',
#        'Colombia; East Timor; Nicaragua',
#        'Colombia; El Salvador; Ethiopia', 'Colombia; El Salvador; Rwanda',
# ...

# %% [markdown]
# Ethiopia

# %%
coffee_fix = coffee_fix.replace({'origin_country':{'Panama; Ethiopia; Costa Rica' : 'Ethiopia; Costa Rica; Panama',
                                          'Ethiopia; El Salvador; Costa Rica' : 'Ethiopia; Costa Rica; El Salvador',
                                          'Guatemala; Honduras; Ethiopia' : 'Ethiopia; Guatemala; Honduras',
                                          'Ethiopia; Kenya; El Salvador' : 'Ethiopia; El Salvador; Kenya',
                                          'Ethiopia; Rwanda; Panama' : 'Ethiopia; Panama; Rwanda',
                                          'Guatemala; El Salvador; Ethiopia' : 'Ethiopia; El Salvador; Guatemala',
                                          'Mexico; Ethiopia; Peru' : 'Ethiopia; Mexico; Peru',
                                          'Panama; Ethiopia; Kenya' : 'Ethiopia; Kenya; Panama',
                                          'Panama; Honduras; Ethiopia' : 'Ethiopia; Honduras; Panama'}})

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Guatemala; Ethiopia; Papua New Guinea', 'Ethiopia; Papua New Guinea; Guatemala'], 
    'Ethiopia; Guatemala; Papua New Guinea'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Ethiopia; Kenya; Costa Rica', 'Kenya; Costa Rica; Ethiopia'], 'Ethiopia; Costa Rica; Kenya'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Ethiopia; Nicaragua; Guatemala', 'Nicaragua; Guatemala; Ethiopia'], 'Ethiopia; Guatemala; Nicaragua'))

# %% [markdown]
# Colombia

# %%
coffee_fix = coffee_fix.replace({'origin_country':{'Ethiopia; Colombia; Honduras' : 'Colombia; Ethiopia; Honduras', 
                                           'Ethiopia; Colombia; Nicaragua' : 'Colombia; Ethiopia; Nicaragua', 
                                           'Colombia; Rwanda; El Salvador' : 'Colombia; El Salvador; Rwanda', 
                                           'Ethiopia; Rwanda; Colombia' : 'Colombia; Ethiopia; Rwanda', 
                                           'Ethiopia; Uganda; Colombia' : 'Colombia; Ethiopia; Uganda', 
                                           'Honduras; Guatemala; Colombia' : 'Colombia; Guatemala; Honduras',
                                           'Indonesia; Kenya; Colombia' : 'Colombia; Indonesia; Kenya', 
                                           'Mexico; Panama; Colombia' : 'Colombia; Mexico; Panama', 
                                           'Nicaragua; Colombia; East Timor' : 'Colombia; East Timor; Nicaragua'}})

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Honduras; Ethiopia; Brazil', 'Ethiopia; Honduras; Brazil'], 'Brazil; Ethiopia; Honduras'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['El Salvador; Colombia; Ethiopia', 'El Salvador; Ethiopia; Colombia'], 'Colombia; El Salvador; Ethiopia'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Ethiopia; Kenya; Colombia', 'Kenya; Ethiopia; Colombia'], 'Colombia; Ethiopia; Kenya'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Colombia; Guatemala; Ethiopia', 'Ethiopia; Colombia; Guatemala', 'Guatemala; Colombia; Ethiopia'], 
    'Colombia; Ethiopia; Guatemala'))

# %% [markdown]
# Brazil

# %%
coffee_fix = coffee_fix.replace({'origin_country':{'Ethiopia; Guatemala; Brazil' : 'Brazil; Ethiopia; Guatemala', 
                                           'Guatemala; Brazil; Indonesia' : 'Brazil; Guatemala; Indonesia', 
                                           'Colombia; Brazil; Indonesia' : 'Brazil; Colombia; Indonesia', 
                                           'Colombia; Brazil; Kenya' : 'Brazil; Colombia; Kenya', 
                                           'Guatemala; Brazil; Kenya' : 'Brazil; Guatemala; Kenya', 
                                           'Guatemala; Brazil; India' : 'Brazil; Guatemala; India', 
                                           'Honduras; Ethiopia; Brazil' : 'Brazil; Ethiopia; Honduras', 
                                           'Indonesia; Costa Rica; Brazil' : 'Brazil; Costa Rica; Indonesia', 
                                           'Kenya; Ethiopia; Brazil' : 'Brazil; Ethiopia; Kenya', 
                                           'Mexico; Ethiopia; Brazil' : 'Brazil; Ethiopia; Mexico', 
                                           'Panama; Brazil; Indonesia' : 'Brazil; Indonesia; Panama', 
                                           'Brazil; Peru; Ecuador' : 'Brazil; Ecuador; Peru', 
                                           'Brazil; Papua New Guinea; Indonesia' : 
                                                   'Brazil; Indonesia; Papua New Guinea'}})

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Ethiopia; Brazil; Costa Rica', 'Brazil; Ethiopia; Costa Rica'], 'Brazil; Costa Rica; Ethiopia'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Columbia; Guatemala; Brazil', 'Guatemala; Colombia; Brazil', 'Guatemala; Brazil; Colombia'], 
    'Brazil; Colombia; Guatemala'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Brazil; Ethiopia; Colombia', 'Ethiopia; Colombia; Brazil'], 'Brazil; Colombia; Ethiopia'))

# %% [markdown]
# Africa, America

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Central America; South America; Africa','South America; Central America; Africa'], 
    'Africa; South America; Central America'))

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(
    'Central America; South America; Ethiopia', 'Ethiopia; Central America; South America')

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(
    'Central America; South America; Indonesia', 'Indonesia; Central America; South America')

# %%
coffee_fix_test12 = coffee_fix[coffee_fix['origin_count'] == 4]
# coffee_fix_test12 = coffee_fix_test12[coffee_fix_test12['origin_country'].str.contains(r"Ethiopia", na=False)]
coffee_fix_test12['origin_country'].sort_values(ascending=True).unique()
# Out:
# array(['Bolivia; Ethiopia; Kenya; Panama',
#        'Brazil; Colombia; Congo; Rwanda',
#        'Brazil; Colombia; Costa Rica; Ethiopia',
#        'Brazil; Colombia; Ethiopia; Guatemala',
#        'Brazil; Costa Rica; Ethiopia; Guatemala',
#        'Brazil; Ethiopia; Guatemala; Indonesia',
#        'Brazil; Guatemala; Ethiopia; Indonesia',
#        'Colombia; Costa Rica; Ethiopia; Guatemala',
#        'Colombia; Costa Rica; Ethiopia; Kenya',
#        'Colombia; Ecuador; Indonesia; Uganda',
#        'Colombia; Ethiopia; Honduras; Indonesia',
#        'Colombia; Ethiopia; Mexico; Panama',
#        'Colombia; Peru; Rwanda; Ethiopia',
#        'Ethiopia; El Salvador; Guatemala; Panama',
#        'Ethiopia; Guatemala; Honduras; Panana',
#        'Ethiopia; Guatemala; Indonesia; Papua New Guinea',
#        'Ethiopia; Kenya; Rwanda; Tanzania'], dtype=object)

# %%
coffee_fix = coffee_fix.replace({'origin_country':{
    'Brazil; Colombia; Rwanda; Congo' : 'Brazil; Colombia; Congo; Rwanda', 
    'Brazil; Costa Rica; Guatemala; Ethiopia' : 'Brazil; Costa Rica; Ethiopia; Guatemala', 
    'Colombia; Ethiopia; Brazil; Costa Rica' : 'Brazil; Colombia; Costa Rica; Ethiopia', 
    'Colombia; Guatemala; Costa Rica; Ethiopia' : 'Colombia; Costa Rica; Ethiopia; Guatemala', 
    'Ethiopia; Colombia; Panama; Mexico' : 'Colombia; Ethiopia; Mexico; Panama', 
    'Ethiopia; Guatemala; Papua New Guinea; Indonesia' : 'Ethiopia; Guatemala; Indonesia; Papua New Guinea', 
    'Ethiopia; Kenya; Bolivia; Panama' : 'Bolivia; Ethiopia; Kenya; Panama', 
    'Ethiopia; Kenya; Colombia; Costa Rica' : 'Colombia; Costa Rica; Ethiopia; Kenya', 
    'Ethiopia; Panama; Guatemala; El Salvador' : 'Ethiopia; El Salvador; Guatemala; Panama', 
    'Ethiopia; Panana; Guatemala; Honduras' : 'Ethiopia; Guatemala; Honduras; Panana', 
    'Guatemala; Ethiopia; Brazil; Indonesia' : 'Brazil; Ethiopia; Guatemala; Indonesia', 
    'Indonesia; Ethiopia; Colombia; Honduras' : 'Colombia; Ethiopia; Honduras; Indonesia', 
    'Kenya; Ethiopia; Tanzania; Rwanda' : 'Ethiopia; Kenya; Rwanda; Tanzania'}})

# %%
coffee_fix['origin_country'] = coffee_fix['origin_country'].replace(dict.fromkeys(
    ['Colombia; Guatemala; Brazil; Ethiopia', 'Ethiopia; Brazil; Guatemala; Colombia', 
     'Ethiopia; Colombia; Guatemala; Brazil', 'Ethiopia; Guatemala; Colombia; Brazil', 
     'Colombia; Guatemala; Ethiopia; Brazil'], 
    'Brazil; Colombia; Ethiopia; Guatemala'))

# %%
coffee_fix_test12 = coffee_fix[coffee_fix['origin_count'] > 4]
# coffee_fix_test12 = coffee_fix_test12[coffee_fix_test12['origin_country'].str.contains(r"Ethiopia", na=False)]
coffee_fix_test12['origin_country'].sort_values(ascending=True).unique()
# Out:
# array(['Brazil; China; Colombia; Ethiopia; Guatemala',
#        'Brazil; Colombia; Cuba; Dominican Republic; Ethiopia; Yemen',
#        'Brazil; Colombia; Ecuador; Ethiopia; Guatemala; Peru',
#        'Brazil; Colombia; El Salvador; Ethiopia; Uganda',
#        'Brazil; Colombia; Ethiopia; Guatemala; Indonesia',
#        'Brazil; Colombia; Ethiopia; Indonesia; Tanzania',
#        'Brazil; Costa Rica; Ethiopia; Guatemala; Indonesia; Nicaragua',
#        'Brazil; Costa Rica; Java; Rwanda; Zambia',
#        'Brazil; Ethiopia; India; Indonesia; Guatemala',
#        'Colombia; Ethiopia; Indonesia; Kenya; Nicaragua',
#        'Costa Rica; El Salvador; Ethiopia; Guatemala; Panama'],
#       dtype=object)

# %%
coffee_fix = coffee_fix.replace({'origin_country':{
    'Brazil; Costa Rica; Zambia; Java; Rwanda' : 'Brazil; Costa Rica; Java; Rwanda; Zambia', 
    'Brazil; Uganda; Colombia; El Salvador; Ethiopia' : 'Brazil; Colombia; El Salvador; Ethiopia; Uganda', 
    'Ethiopia; Brazil; India; Indonesia; Guatemala' : 'Brazil; Ethiopia; India; Indonesia; Guatemala', 
    'Ethiopia; Colombia; Brazil; Tanzania; Indonesia' : 'Brazil; Colombia; Ethiopia; Indonesia; Tanzania', 
    'Ethiopia; Colombia; Dominican Republic; Brazil; Cuba; Yemen' : 
    'Brazil; Colombia; Cuba; Dominican Republic; Ethiopia; Yemen', 
    'Ethiopia; Guatemala; El Salvador; Panama; Costa Rica' : 'Costa Rica; El Salvador; Ethiopia; Guatemala; Panama', 
    'Ethiopia; Kenya; Colombia; Nicaragua; Indonesia' : 'Colombia; Ethiopia; Indonesia; Kenya; Nicaragua', 
    'Guatemala; Colombia; Brazil; Ethiopia; China' : 'Brazil; China; Colombia; Ethiopia; Guatemala', 
    'Guatemala; Nicaragua; Ethiopia; Costa Rica; Indonesia; Brazil' : 
    'Brazil; Costa Rica; Ethiopia; Guatemala; Indonesia; Nicaragua', 
    'Peru; Colombia; Guatemala; Ecuador; Ethiopia; Brazil' : 'Brazil; Colombia; Ecuador; Ethiopia; Guatemala; Peru', 
    'Ethiopia; Indonesia; Colombia; Brazil; Guatemala' : 'Brazil; Colombia; Ethiopia; Guatemala; Indonesia'}})

# %%
coffee_fix['agtron'].sort_values(ascending=True).unique()
# Out:
# array(['/', '/58', '0/0', '0/37', '31/44', '32/44', '34/44', '35/48',
#        '36/44', '36/48', '37/49', '38/46', '38/50', '38/52', '39/45',
#        '39/53', '39/57', '39/61', '40/48', '40/49', '40/50', '40/52',
#        '40/53', '40/54', '40/56', '40/60', '41/53', '41/55', '42/49',
#        '42/54', '42/56', '42/57', '42/58', '42/60', '42/62', '42/64',
#        '42/66', '42/68', '43/50', '43/54', '43/59', '43/63', '44/52',
#        '44/58', '44/60', '44/61', '44/62', '44/66', '44/70', '45/54',
#        '45/58', '45/59', '45/60', '45/61', '45/63', '45/65', '45/67',
#        '45/69', '45/70', '45/75', '46/58', '46/60', '46/62', '46/64',
#        '46/66', '46/67', '46/68', '46/70', '46/72', '46/74', '46/76',
#        '47/55', '47/57', '47/59', '47/60', '47/61', '47/62', '47/63',
#        '47/64', '47/65', '47/67', '47/69', '47/70', '47/71', '47/72',
#        '47/73', '47/76', '47/77', '48/56', '48/57', '48/58', '48/60',
# ...

# %%
coffee_fix['agtron'] = coffee_fix['agtron'].replace(dict.fromkeys(['NA/','/', 'NA/NA'], '0/0'))

# %%
coffee_fix['agtron'] = coffee_fix['agtron'].replace('/58', '0/58')

# %%
coffee_fix['agtron'] = coffee_fix['agtron'].replace('5252/70', '52/70')

# %%
coffee_fix['agtron'] = coffee_fix['agtron'].replace('547/74', '54/74')

# %%
coffee_fix['agtron'] = coffee_fix['agtron'].replace('555/73', '55/73')

# %%
agtron_grounds = coffee_fix['agtron'].str.split('/').str[0]
agtron_grounds.unique()
# Out:
# array(['50', '54', '53', '48', '66', '58', '47', '55', '51', '52', '56',
#        '0', '38', '71', '44', '42', '63', '62', '57', '61', '46', '45',
#        '60', '65', '40', '49', '43', '59', '41', '39', '37', '69', '36',
#        '64', '31', '67', '68', '85', '79', '74', '82', '35', '76', '32',
#        '34', '75', '72'], dtype=object)

# %%
agtron_bean = coffee_fix['agtron'].str.split('/').str[-1]
agtron_bean.unique()
# Out:
# array(['73', '77', '70', '79', '92', '75', '80', '81', '72', '65', '74',
#        '66', '68', '76', '78', '37', '52', '99', '97', '58', '84', '82',
#        '86', '69', '85', '67', '93', '71', '87', '60', '57', '88', '91',
#        '54', '62', '0', '53', '83', '64', '48', '45', '50', '63', '55',
#        '61', '90', '49', '59', '44', '46', '56', '96', '105', '94', '104'],
#       dtype=object)

# %%
coffee_fix['agtron_grounds'] = agtron_grounds

# %%
coffee_fix['agtron_bean'] = agtron_bean

# %%
coffee_fix[['agtron_grounds','agtron_bean']] = coffee_fix[['agtron_grounds','agtron_bean']] .astype(int)

# %%
coffee_fix['roast'] = coffee_fix['roast'].fillna('Light')

# %%
coffee_fix.iloc[458,8] = '$15.45/12 ounces'

# %%
coffee_fix.iloc[751,8] = '$22.95/12 ounces'

# %%
coffee_fix.iloc[1753,8] = '$30.00/6 ounces'

# %%
coffee_fix.iloc[1754,8] = '280.00/70 grams'

# %%
coffee_fix.iloc[232,8] = '$12.00/25.4-ounce bottle'

# %%
coffee_fix.iloc[237,8] = '$5.50/10.5 ounce bottle'

# %%
coffee_fix.iloc[240,8] = '$3.00/9.5-ounce can'

# %%
coffee_fix.iloc[241,8] = '$7.00/12-ounces bottle'

# %%
coffee_fix.iloc[928,8] = '$5.00/12 ounce bottle'

# %%
coffee_fix.iloc[929,8] = '$4.00/12 ounce bottle'

# %%
coffee_fix.iloc[933,8] = '$3.90/9.5 ounce can'

# %%
coffee_fix.iloc[934,8] = '$4.50/12 ounce bottle'

# %%
coffee_fix['aroma'] = coffee_fix['aroma'].fillna(0.0)

# %%
coffee_fix['acid'] = coffee_fix['acid'].fillna(0.0)

# %%
coffee_fix['with_milk'] = coffee_fix['with_milk'].fillna(0.0)

# %%
coffee_fix = coffee_fix.drop([158, 361, 520, 863, 1210])

# %%
coffee_fix.to_csv('../data/coffee_fix_clean.csv', index=False)
